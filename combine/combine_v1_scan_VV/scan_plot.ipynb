# %%
import os, subprocess
import json
import uproot
import awkward as ak
import numpy as np
from coffea import processor, util, hist
import pandas as pd
import pickle

#Plot settings
# %matplotlib inline
import matplotlib.pyplot as plt
import mplhep as hep
plt.style.use(hep.style.CMS)

import matplotlib.pylab as pylab
params = {'legend.fontsize': 'medium',
         'axes.labelsize': 'x-large',
         'axes.titlesize':'x-large',
         'xtick.labelsize':'medium',
         'ytick.labelsize':'medium'}
pylab.rcParams.update(params)

#line thickness
import matplotlib as mpl
#mpl.rcParams['lines.linewidth'] = 5

#Dataset parameters
lumis = {}
lumis['2016'] = 35.9
lumis['2017'] = 41.5
lumis['2018'] = 59.9

with open('../../files/xsec.json') as f:
    xs = json.load(f)

with open('../../files/pmap.json') as f:
    pmap = json.load(f)

systematics = ['nominal',
               'jet_triggerUp','jet_triggerDown',
               'btagWeightUp','btagWeightDown','btagEffStatUp','btagEffStatDown',
               'UESUp','UESDown','JESUp','JESDown','JERUp','JERDown',
              ]

# %%
ParticleNet_WorkingPoints = {
        '2016APV_bb':    [0.0, 0.9088, 0.9737, 0.9883],
        '2016APV_cc':    [0.0, 0.9252, 0.9751, 0.9909],
        
        '2016_bb': [0.0, 0.9137, 0.9735, 0.9883],
        '2016_cc': [0.0, 0.9252, 0.9743, 0.9905],
        
        '2017_bb':    [0.0, 0.9105, 0.9714, 0.9870],
        '2017_cc':    [0.0, 0.9347, 0.9765, 0.9909],
        
        '2018_bb':    [0.0, 0.9172, 0.9734, 0.9880],
        '2018_cc':    [0.0, 0.9368, 0.9777, 0.9917]
}

# %%
#Define the year here
year = '2017'

# %% [markdown]
# ## Get significance from combine scan

# %%
#Open one file and extract the thresholds and significance
def open_file_and_extract(file_path):
    
    thresholds_temp = []
    thresholds = []
    significance = []
    status = []
    
    with open(file_path) as f:
        lines = f.read().splitlines()
        
    for x in lines:
        
        if x.endswith('>>>') and not x.startswith('>>>'):
            thresholds_temp.append([float(y[5:]) for y in x[:-4].split(';')])
            
        if x.startswith('Significance:'):            
            significance.append(float(x[14:]))
            thresholds.append(thresholds_temp[-1])
            
        if x.startswith('INFO: (function: improveOnce) CascadeMinimizer.cc: 211 -- Minimisation finished with status=-1'): status.append(-1)
        if x.startswith('INFO: (function: improveOnce) CascadeMinimizer.cc: 211 -- Minimisation finished with status=0'): status.append(0)
        
    
    for i in range(len(significance)):
        if status[2*i] + status[2*i+1]< 0:
            significance[i] = -1
        
#     print("Thresholds: {}. Length: {}".format(thresholds,len(thresholds)))
#     print("Significance: ", significance)
#     print("Status: {}. Length: {}".format(status, len(status)))
    
    return thresholds, significance, status
    
def scan_logs_out(log_dir):
    
    ddb_thres = []
    ddc_thres = []
    all_sign = []
    all_status = []
    
    #Loop over the files
    for file in os.listdir(log_dir):
        
        filename = os.fsdecode(file)
        if filename.endswith(".out"):
            local_thres, local_sign, local_status = open_file_and_extract(os.path.join(log_dir,filename))
            
            if len(local_sign) > 0:
                    ddb_thres += [x[0] for x in local_thres]
                    ddc_thres += [x[1] for x in local_thres]
                    all_sign += local_sign
                    all_status += local_status
#             elif len(local_sign) < 10:
#                 print("local thres:", local_thres)
#                 print("Local sign: ", local_sign)
                
    return np.asarray(ddb_thres), np.asarray(ddc_thres), np.asarray(all_sign), np.asarray(all_status)
            
ddb, ddc, sign, status = scan_logs_out("logs/")

# %%
fig, ax = plt.subplots()
im = ax.scatter(ddc, ddb, c=sign, s=1000, marker='s', cmap='Spectral_r',linewidths=0, vmin=1.3, vmax=2.2)

cbar = fig.colorbar(im, ax=ax)
cbar.set_label(r'VV Significance ($\sigma$)')

hep.cms.text("Preliminary")
hep.cms.lumitext(f"{year} MC, {lumis[year]} $fb^{-1}$ (13 TeV)", fontsize=15)

plt.xlabel(r"$\geq$ Jet 2 ccvdQCD")
plt.ylabel(r"$\geq$ Jet 1 bbvsQCD")
plt.xlim([0.0,1])
plt.ylim([0.98,1])
WP = plt.axhline(y=ParticleNet_WorkingPoints[f'{year}_bb'][3],
            color='r',
            linestyle='-',
            label=f'{year} HP WP')

plt.legend([WP], [f'{year} bb HP WP'], loc = 'lower left')
#plt.xscale('log')

# %%
d = {'Jet 1 b': ddb, 'Jet 2 c': ddc, 'significance':sign}
df = pd.DataFrame(data=d)

# %%
df['significance']
# Out:
# 0       1.10076
# 1       1.21729
# 2       1.22912
# 3       1.13576
# 4       1.06293
#          ...
# 2445    1.19748
# 2446    1.21338
# 2447    1.23884
# 2448    1.25497
# 2449    1.25064
# Name: significance, Length: 2450, dtype: float64

# %%
df_print.iloc[0]['Jet 1 b']
# Out:
# 0.99265

# %%
df_print = df[(df['significance'] > 1.35)  & (df['Jet 1 b']  < 0.9900)  & (df['Jet 1 b']  > 0.9875)]

for i in range(len(df_print)):
    print("---------")
    print("B Threshold: ",df_print.iloc[i]['Jet 1 b'])
    print("C Threshold: ", df_print.iloc[i]['Jet 2 c'])
    print("Significance: ", df_print.iloc[i]['significance'])
# Out:
# ---------
# B Threshold:  0.9886
# C Threshold:  0.8367
# Significance:  1.83881
# ---------
# B Threshold:  0.9886
# C Threshold:  0.8571
# Significance:  1.84942
# ---------
# B Threshold:  0.9886
# C Threshold:  0.8776
# Significance:  1.85805
# ---------
# B Threshold:  0.9886
# C Threshold:  0.898
# Significance:  1.87983
# ---------
# B Threshold:  0.9886
# C Threshold:  0.9184
# Significance:  1.87739
# ---------
# B Threshold:  0.9886
# C Threshold:  0.9347
# Significance:  1.9534
# ---------
# B Threshold:  0.9886
# C Threshold:  0.9388
# Significance:  1.91578
# ---------
# B Threshold:  0.9878
# C Threshold:  0.9184
# Significance:  1.87665
# ---------
# B Threshold:  0.9878
# C Threshold:  0.9347
# Significance:  1.95497
# ---------
# B Threshold:  0.9878
# C Threshold:  0.9388
# Significance:  1.9211
# ---------
# B Threshold:  0.9886
# C Threshold:  0.4286
# Significance:  1.78197
# ---------
# B Threshold:  0.9886
# C Threshold:  0.449
# Significance:  1.77611
# ---------
# B Threshold:  0.9886
# C Threshold:  0.4694
# Significance:  1.77346
# ---------
# B Threshold:  0.9886
# C Threshold:  0.4898
# Significance:  1.78391
# ---------
# B Threshold:  0.9886
# C Threshold:  0.5102
# Significance:  1.80687
# ---------
# B Threshold:  0.9886
# C Threshold:  0.5306
# Significance:  1.80369
# ---------
# B Threshold:  0.9886
# C Threshold:  0.551
# Significance:  1.79154
# ---------
# B Threshold:  0.9886
# C Threshold:  0.5714
# Significance:  1.79268
# ---------
# B Threshold:  0.9886
# C Threshold:  0.5918
# Significance:  1.79507
# ---------
# B Threshold:  0.9886
# C Threshold:  0.6122
# Significance:  1.78312
# ---------
# B Threshold:  0.9898
# C Threshold:  0.9184
# Significance:  1.93579
# ---------
# B Threshold:  0.9898
# C Threshold:  0.9347
# Significance:  1.98414
# ---------
# B Threshold:  0.9898
# C Threshold:  0.9388
# Significance:  1.94504
# ---------
# B Threshold:  0.9878
# C Threshold:  0.102
# Significance:  1.58271
# ---------
# B Threshold:  0.9878
# C Threshold:  0.1224
# Significance:  1.60341
# ---------
# B Threshold:  0.9878
# C Threshold:  0.1429
# Significance:  1.62012
# ---------
# B Threshold:  0.9878
# C Threshold:  0.1633
# Significance:  1.65326
# ---------
# B Threshold:  0.9878
# C Threshold:  0.1837
# Significance:  1.651
# ---------
# B Threshold:  0.9878
# C Threshold:  0.2041
# Significance:  1.65893
# ---------
# B Threshold:  0.9878
# C Threshold:  0.2245
# Significance:  1.67707
# ---------
# B Threshold:  0.9878
# C Threshold:  0.2449
# Significance:  1.67286
# ---------
# B Threshold:  0.9878
# C Threshold:  0.2653
# Significance:  1.68994
# ---------
# B Threshold:  0.9878
# C Threshold:  0.2857
# Significance:  1.7275
# ---------
# B Threshold:  0.989
# C Threshold:  0.1837
# Significance:  1.66881
# ---------
# B Threshold:  0.989
# C Threshold:  0.2041
# Significance:  1.67715
# ---------
# B Threshold:  0.989
# C Threshold:  0.2245
# Significance:  1.69755
# ---------
# B Threshold:  0.989
# C Threshold:  0.2449
# Significance:  1.68622
# ---------
# B Threshold:  0.989
# C Threshold:  0.2653
# Significance:  1.70479
# ---------
# B Threshold:  0.989
# C Threshold:  0.2857
# Significance:  1.74354
# ---------
# B Threshold:  0.989
# C Threshold:  0.3061
# Significance:  1.75686
# ---------
# B Threshold:  0.989
# C Threshold:  0.3265
# Significance:  1.75707
# ---------
# B Threshold:  0.989
# C Threshold:  0.3469
# Significance:  1.7493
# ---------
# B Threshold:  0.989
# C Threshold:  0.3673
# Significance:  1.77335
# ---------
# B Threshold:  0.989
# C Threshold:  0.5918
# Significance:  1.80426
# ---------
# B Threshold:  0.989
# C Threshold:  0.6122
# Significance:  1.79193
# ---------
# B Threshold:  0.989
# C Threshold:  0.6327
# Significance:  1.76973
# ---------
# B Threshold:  0.989
# C Threshold:  0.6531
# Significance:  1.7822
# ---------
# B Threshold:  0.989
# C Threshold:  0.6735
# Significance:  1.787
# ---------
# B Threshold:  0.989
# C Threshold:  0.6939
# Significance:  1.78836
# ---------
# B Threshold:  0.989
# C Threshold:  0.7143
# Significance:  1.81187
# ---------
# B Threshold:  0.989
# C Threshold:  0.7347
# Significance:  1.8043
# ---------
# B Threshold:  0.989
# C Threshold:  0.7551
# Significance:  1.81754
# ---------
# B Threshold:  0.989
# C Threshold:  0.7755
# Significance:  1.82092
# ---------
# B Threshold:  0.9882
# C Threshold:  0.4694
# Significance:  1.76566
# ---------
# B Threshold:  0.9882
# C Threshold:  0.4898
# Significance:  1.77597
# ---------
# B Threshold:  0.9882
# C Threshold:  0.5102
# Significance:  1.79852
# ---------
# B Threshold:  0.9882
# C Threshold:  0.5306
# Significance:  1.79514
# ---------
# B Threshold:  0.9882
# C Threshold:  0.551
# Significance:  1.7826
# ---------
# B Threshold:  0.9882
# C Threshold:  0.5714
# Significance:  1.78387
# ---------
# B Threshold:  0.9882
# C Threshold:  0.5918
# Significance:  1.7861
# ---------
# B Threshold:  0.9882
# C Threshold:  0.6122
# Significance:  1.77419
# ---------
# B Threshold:  0.9882
# C Threshold:  0.6327
# Significance:  1.75353
# ---------
# B Threshold:  0.9882
# C Threshold:  0.6531
# Significance:  1.76581
# ---------
# B Threshold:  0.9878
# C Threshold:  0.3061
# Significance:  1.74078
# ---------
# B Threshold:  0.9878
# C Threshold:  0.3265
# Significance:  1.74068
# ---------
# B Threshold:  0.9878
# C Threshold:  0.3469
# Significance:  1.73241
# ---------
# B Threshold:  0.9878
# C Threshold:  0.3673
# Significance:  1.75624
# ---------
# B Threshold:  0.9878
# C Threshold:  0.3878
# Significance:  1.74942
# ---------
# B Threshold:  0.9878
# C Threshold:  0.4082
# Significance:  1.7601
# ---------
# B Threshold:  0.9878
# C Threshold:  0.4286
# Significance:  1.77048
# ---------
# B Threshold:  0.9878
# C Threshold:  0.449
# Significance:  1.76504
# ---------
# B Threshold:  0.9878
# C Threshold:  0.4694
# Significance:  1.76249
# ---------
# B Threshold:  0.9878
# C Threshold:  0.4898
# Significance:  1.77227
# ---------
# B Threshold:  0.9898
# C Threshold:  0.7143
# Significance:  1.84426
# ---------
# B Threshold:  0.9898
# C Threshold:  0.7347
# Significance:  1.83665
# ---------
# B Threshold:  0.9898
# C Threshold:  0.7551
# Significance:  1.85114
# ---------
# B Threshold:  0.9898
# C Threshold:  0.7755
# Significance:  1.85301
# ---------
# B Threshold:  0.9898
# C Threshold:  0.7959
# Significance:  1.87382
# ---------
# B Threshold:  0.9898
# C Threshold:  0.8163
# Significance:  1.8813
# ---------
# B Threshold:  0.9898
# C Threshold:  0.8367
# Significance:  1.88967
# ---------
# B Threshold:  0.9898
# C Threshold:  0.8571
# Significance:  1.90342
# ---------
# B Threshold:  0.9898
# C Threshold:  0.8776
# Significance:  1.91293
# ---------
# B Threshold:  0.9898
# C Threshold:  0.898
# Significance:  1.93518
# ---------
# B Threshold:  0.9882
# C Threshold:  0.6735
# Significance:  1.77039
# ---------
# B Threshold:  0.9882
# C Threshold:  0.6939
# Significance:  1.77108
# ---------
# B Threshold:  0.9882
# C Threshold:  0.7143
# Significance:  1.79344
# ---------
# B Threshold:  0.9882
# C Threshold:  0.7347
# Significance:  1.7856
# ---------
# B Threshold:  0.9882
# C Threshold:  0.7551
# Significance:  1.79849
# ---------
# B Threshold:  0.9882
# C Threshold:  0.7755
# Significance:  1.80384
# ---------
# B Threshold:  0.9882
# C Threshold:  0.7959
# Significance:  1.81827
# ---------
# B Threshold:  0.9882
# C Threshold:  0.8163
# Significance:  1.82321
# ---------
# B Threshold:  0.9882
# C Threshold:  0.8367
# Significance:  1.82597
# ---------
# B Threshold:  0.9882
# C Threshold:  0.8571
# Significance:  1.83794
# ---------
# B Threshold:  0.9886
# C Threshold:  0.0204
# Significance:  1.46019
# ---------
# B Threshold:  0.9886
# C Threshold:  0.0408
# Significance:  1.51076
# ---------
# B Threshold:  0.9886
# C Threshold:  0.0612
# Significance:  1.53898
# ---------
# B Threshold:  0.9886
# C Threshold:  0.0816
# Significance:  1.55982
# ---------
# B Threshold:  0.9886
# C Threshold:  0.102
# Significance:  1.58584
# ---------
# B Threshold:  0.9886
# C Threshold:  0.1224
# Significance:  1.60732
# ---------
# B Threshold:  0.9886
# C Threshold:  0.1429
# Significance:  1.62304
# ---------
# B Threshold:  0.9886
# C Threshold:  0.1633
# Significance:  1.66182
# ---------
# B Threshold:  0.9886
# C Threshold:  0.1837
# Significance:  1.65783
# ---------
# B Threshold:  0.9886
# C Threshold:  0.2041
# Significance:  1.66574
# ---------
# B Threshold:  0.9882
# C Threshold:  0.8776
# Significance:  1.84876
# ---------
# B Threshold:  0.9882
# C Threshold:  0.898
# Significance:  1.87172
# ---------
# B Threshold:  0.9882
# C Threshold:  0.9184
# Significance:  1.87033
# ---------
# B Threshold:  0.9882
# C Threshold:  0.9347
# Significance:  1.94568
# ---------
# B Threshold:  0.9882
# C Threshold:  0.9388
# Significance:  1.90981
# ---------
# B Threshold:  0.9878
# C Threshold:  0.5102
# Significance:  1.79463
# ---------
# B Threshold:  0.9878
# C Threshold:  0.5306
# Significance:  1.79102
# ---------
# B Threshold:  0.9878
# C Threshold:  0.551
# Significance:  1.77902
# ---------
# B Threshold:  0.9878
# C Threshold:  0.5714
# Significance:  1.78075
# ---------
# B Threshold:  0.9878
# C Threshold:  0.5918
# Significance:  1.77928
# ---------
# B Threshold:  0.9878
# C Threshold:  0.6122
# Significance:  1.76361
# ---------
# B Threshold:  0.9878
# C Threshold:  0.6327
# Significance:  1.74417
# ---------
# B Threshold:  0.9878
# C Threshold:  0.6531
# Significance:  1.75656
# ---------
# B Threshold:  0.9878
# C Threshold:  0.6735
# Significance:  1.76064
# ---------
# B Threshold:  0.9878
# C Threshold:  0.6939
# Significance:  1.75979
# ---------
# B Threshold:  0.989
# C Threshold:  0.3878
# Significance:  1.76678
# ---------
# B Threshold:  0.989
# C Threshold:  0.4082
# Significance:  1.77892
# ---------
# B Threshold:  0.989
# C Threshold:  0.4286
# Significance:  1.79014
# ---------
# B Threshold:  0.989
# C Threshold:  0.449
# Significance:  1.78419
# ---------
# B Threshold:  0.989
# C Threshold:  0.4694
# Significance:  1.78155
# ---------
# B Threshold:  0.989
# C Threshold:  0.4898
# Significance:  1.79109
# ---------
# B Threshold:  0.989
# C Threshold:  0.5102
# Significance:  1.81434
# ---------
# B Threshold:  0.989
# C Threshold:  0.5306
# Significance:  1.81129
# ---------
# B Threshold:  0.989
# C Threshold:  0.551
# Significance:  1.79964
# ---------
# B Threshold:  0.989
# C Threshold:  0.5714
# Significance:  1.80107
# ---------
# B Threshold:  0.9886
# C Threshold:  0.6327
# Significance:  1.76104
# ---------
# B Threshold:  0.9886
# C Threshold:  0.6531
# Significance:  1.77349
# ---------
# B Threshold:  0.9886
# C Threshold:  0.6735
# Significance:  1.77817
# ---------
# B Threshold:  0.9886
# C Threshold:  0.6939
# Significance:  1.77948
# ---------
# B Threshold:  0.9886
# C Threshold:  0.7143
# Significance:  1.80316
# ---------
# B Threshold:  0.9886
# C Threshold:  0.7347
# Significance:  1.79557
# ---------
# B Threshold:  0.9886
# C Threshold:  0.7551
# Significance:  1.8088
# ---------
# B Threshold:  0.9886
# C Threshold:  0.7755
# Significance:  1.81327
# ---------
# B Threshold:  0.9886
# C Threshold:  0.7959
# Significance:  1.82932
# ---------
# B Threshold:  0.9886
# C Threshold:  0.8163
# Significance:  1.83502
# ---------
# B Threshold:  0.9894
# C Threshold:  0.9388
# Significance:  1.93436
# ---------
# B Threshold:  0.9886
# C Threshold:  0.2245
# Significance:  1.68471
# ---------
# B Threshold:  0.9886
# C Threshold:  0.2449
# Significance:  1.68043
# ---------
# B Threshold:  0.9886
# C Threshold:  0.2653
# Significance:  1.69872
# ---------
# B Threshold:  0.9886
# C Threshold:  0.2857
# Significance:  1.73682
# ---------
# B Threshold:  0.9886
# C Threshold:  0.3061
# Significance:  1.75013
# ---------
# B Threshold:  0.9886
# C Threshold:  0.3265
# Significance:  1.75034
# ---------
# B Threshold:  0.9886
# C Threshold:  0.3469
# Significance:  1.74205
# ---------
# B Threshold:  0.9886
# C Threshold:  0.3673
# Significance:  1.7659
# ---------
# B Threshold:  0.9886
# C Threshold:  0.3878
# Significance:  1.75949
# ---------
# B Threshold:  0.9886
# C Threshold:  0.4082
# Significance:  1.77127
# ---------
# B Threshold:  0.9878
# C Threshold:  0.7143
# Significance:  1.78187
# ---------
# B Threshold:  0.9878
# C Threshold:  0.7347
# Significance:  1.7731
# ---------
# B Threshold:  0.9878
# C Threshold:  0.7551
# Significance:  1.78567
# ---------
# B Threshold:  0.9878
# C Threshold:  0.7755
# Significance:  1.79221
# ---------
# B Threshold:  0.9878
# C Threshold:  0.7959
# Significance:  1.80595
# ---------
# B Threshold:  0.9878
# C Threshold:  0.8163
# Significance:  1.80903
# ---------
# B Threshold:  0.9878
# C Threshold:  0.8367
# Significance:  1.82675
# ---------
# B Threshold:  0.9878
# C Threshold:  0.8571
# Significance:  1.83708
# ---------
# B Threshold:  0.9878
# C Threshold:  0.8776
# Significance:  1.84789
# ---------
# B Threshold:  0.9878
# C Threshold:  0.898
# Significance:  1.87366
# ---------
# B Threshold:  0.9882
# C Threshold:  0.2653
# Significance:  1.69328
# ---------
# B Threshold:  0.9882
# C Threshold:  0.2857
# Significance:  1.73061
# ---------
# B Threshold:  0.9882
# C Threshold:  0.3061
# Significance:  1.74405
# ---------
# B Threshold:  0.9882
# C Threshold:  0.3265
# Significance:  1.74407
# ---------
# B Threshold:  0.9882
# C Threshold:  0.3469
# Significance:  1.73558
# ---------
# B Threshold:  0.9882
# C Threshold:  0.3673
# Significance:  1.75961
# ---------
# B Threshold:  0.9882
# C Threshold:  0.3878
# Significance:  1.75319
# ---------
# B Threshold:  0.9882
# C Threshold:  0.4082
# Significance:  1.76461
# ---------
# B Threshold:  0.9882
# C Threshold:  0.4286
# Significance:  1.77464
# ---------
# B Threshold:  0.9882
# C Threshold:  0.449
# Significance:  1.76855
# ---------
# B Threshold:  0.9882
# C Threshold:  0.0612
# Significance:  1.53036
# ---------
# B Threshold:  0.9882
# C Threshold:  0.0816
# Significance:  1.5509
# ---------
# B Threshold:  0.9882
# C Threshold:  0.102
# Significance:  1.58161
# ---------
# B Threshold:  0.9882
# C Threshold:  0.1224
# Significance:  1.60264
# ---------
# B Threshold:  0.9882
# C Threshold:  0.1429
# Significance:  1.61829
# ---------
# B Threshold:  0.9882
# C Threshold:  0.1633
# Significance:  1.65659
# ---------
# B Threshold:  0.9882
# C Threshold:  0.1837
# Significance:  1.65302
# ---------
# B Threshold:  0.9882
# C Threshold:  0.2041
# Significance:  1.6614
# ---------
# B Threshold:  0.9882
# C Threshold:  0.2245
# Significance:  1.67975
# ---------
# B Threshold:  0.9882
# C Threshold:  0.2449
# Significance:  1.67522
# ---------
# B Threshold:  0.9894
# C Threshold:  0.1429
# Significance:  1.63531
# ---------
# B Threshold:  0.9894
# C Threshold:  0.1633
# Significance:  1.6764
# ---------
# B Threshold:  0.9894
# C Threshold:  0.1837
# Significance:  1.67107
# ---------
# B Threshold:  0.9894
# C Threshold:  0.2041
# Significance:  1.68029
# ---------
# B Threshold:  0.9894
# C Threshold:  0.2245
# Significance:  1.69459
# ---------
# B Threshold:  0.9894
# C Threshold:  0.2449
# Significance:  1.69029
# ---------
# B Threshold:  0.9894
# C Threshold:  0.2653
# Significance:  1.70658
# ---------
# B Threshold:  0.9894
# C Threshold:  0.2857
# Significance:  1.74637
# ---------
# B Threshold:  0.9894
# C Threshold:  0.3061
# Significance:  1.7598
# ---------
# B Threshold:  0.9894
# C Threshold:  0.3265
# Significance:  1.76025
# ---------
# B Threshold:  0.9894
# C Threshold:  0.3469
# Significance:  1.75166
# ---------
# B Threshold:  0.9894
# C Threshold:  0.3673
# Significance:  1.77619
# ---------
# B Threshold:  0.9894
# C Threshold:  0.3878
# Significance:  1.77003
# ---------
# B Threshold:  0.9894
# C Threshold:  0.4082
# Significance:  1.78236
# ---------
# B Threshold:  0.9894
# C Threshold:  0.4286
# Significance:  1.79452
# ---------
# B Threshold:  0.9894
# C Threshold:  0.449
# Significance:  1.78842
# ---------
# B Threshold:  0.9894
# C Threshold:  0.4694
# Significance:  1.78545
# ---------
# B Threshold:  0.9894
# C Threshold:  0.4898
# Significance:  1.79515
# ---------
# B Threshold:  0.9894
# C Threshold:  0.5102
# Significance:  1.81895
# ---------
# B Threshold:  0.9894
# C Threshold:  0.5306
# Significance:  1.81612
# ---------
# B Threshold:  0.9894
# C Threshold:  0.7551
# Significance:  1.82098
# ---------
# B Threshold:  0.9894
# C Threshold:  0.7755
# Significance:  1.82466
# ---------
# B Threshold:  0.9894
# C Threshold:  0.7959
# Significance:  1.84132
# ---------
# B Threshold:  0.9894
# C Threshold:  0.8163
# Significance:  1.84772
# ---------
# B Threshold:  0.9894
# C Threshold:  0.8367
# Significance:  1.85259
# ---------
# B Threshold:  0.9894
# C Threshold:  0.8571
# Significance:  1.86397
# ---------
# B Threshold:  0.9894
# C Threshold:  0.8776
# Significance:  1.87199
# ---------
# B Threshold:  0.9894
# C Threshold:  0.898
# Significance:  1.8939
# ---------
# B Threshold:  0.9894
# C Threshold:  0.9184
# Significance:  1.89664
# ---------
# B Threshold:  0.9894
# C Threshold:  0.9347
# Significance:  1.9725
# ---------
# B Threshold:  0.989
# C Threshold:  0.7959
# Significance:  1.83814
# ---------
# B Threshold:  0.989
# C Threshold:  0.8163
# Significance:  1.84443
# ---------
# B Threshold:  0.989
# C Threshold:  0.8367
# Significance:  1.84873
# ---------
# B Threshold:  0.989
# C Threshold:  0.8571
# Significance:  1.85956
# ---------
# B Threshold:  0.989
# C Threshold:  0.8776
# Significance:  1.86801
# ---------
# B Threshold:  0.989
# C Threshold:  0.898
# Significance:  1.88876
# ---------
# B Threshold:  0.989
# C Threshold:  0.9184
# Significance:  1.8876
# ---------
# B Threshold:  0.989
# C Threshold:  0.9347
# Significance:  1.96522
# ---------
# B Threshold:  0.989
# C Threshold:  0.9388
# Significance:  1.9281
# ---------
# B Threshold:  0.9898
# C Threshold:  0.102
# Significance:  1.6145
# ---------
# B Threshold:  0.9898
# C Threshold:  0.1224
# Significance:  1.62794
# ---------
# B Threshold:  0.9898
# C Threshold:  0.1429
# Significance:  1.64439
# ---------
# B Threshold:  0.9898
# C Threshold:  0.1633
# Significance:  1.68662
# ---------
# B Threshold:  0.9898
# C Threshold:  0.1837
# Significance:  1.68116
# ---------
# B Threshold:  0.9898
# C Threshold:  0.2041
# Significance:  1.69043
# ---------
# B Threshold:  0.9898
# C Threshold:  0.2245
# Significance:  1.70557
# ---------
# B Threshold:  0.9898
# C Threshold:  0.2449
# Significance:  1.70106
# ---------
# B Threshold:  0.9898
# C Threshold:  0.2653
# Significance:  1.71825
# ---------
# B Threshold:  0.9898
# C Threshold:  0.2857
# Significance:  1.76012
# ---------
# B Threshold:  0.9898
# C Threshold:  0.5102
# Significance:  1.8372
# ---------
# B Threshold:  0.9898
# C Threshold:  0.5306
# Significance:  1.83525
# ---------
# B Threshold:  0.9898
# C Threshold:  0.551
# Significance:  1.81878
# ---------
# B Threshold:  0.9898
# C Threshold:  0.5714
# Significance:  1.82057
# ---------
# B Threshold:  0.9898
# C Threshold:  0.5918
# Significance:  1.81971
# ---------
# B Threshold:  0.9898
# C Threshold:  0.6122
# Significance:  1.8192
# ---------
# B Threshold:  0.9898
# C Threshold:  0.6327
# Significance:  1.79656
# ---------
# B Threshold:  0.9898
# C Threshold:  0.6531
# Significance:  1.80984
# ---------
# B Threshold:  0.9898
# C Threshold:  0.6735
# Significance:  1.81594
# ---------
# B Threshold:  0.9898
# C Threshold:  0.6939
# Significance:  1.81898
# ---------
# B Threshold:  0.9894
# C Threshold:  0.551
# Significance:  1.80305
# ---------
# B Threshold:  0.9894
# C Threshold:  0.5714
# Significance:  1.80375
# ---------
# B Threshold:  0.9894
# C Threshold:  0.5918
# Significance:  1.80681
# ---------
# B Threshold:  0.9894
# C Threshold:  0.6122
# Significance:  1.79535
# ---------
# B Threshold:  0.9894
# C Threshold:  0.6327
# Significance:  1.77306
# ---------
# B Threshold:  0.9894
# C Threshold:  0.6531
# Significance:  1.78591
# ---------
# B Threshold:  0.9894
# C Threshold:  0.6735
# Significance:  1.79076
# ---------
# B Threshold:  0.9894
# C Threshold:  0.6939
# Significance:  1.79256
# ---------
# B Threshold:  0.9894
# C Threshold:  0.7143
# Significance:  1.81564
# ---------
# B Threshold:  0.9894
# C Threshold:  0.7347
# Significance:  1.8078
# ---------
# B Threshold:  0.9898
# C Threshold:  0.3061
# Significance:  1.77463
# ---------
# B Threshold:  0.9898
# C Threshold:  0.3265
# Significance:  1.77664
# ---------
# B Threshold:  0.9898
# C Threshold:  0.3469
# Significance:  1.7682
# ---------
# B Threshold:  0.9898
# C Threshold:  0.3673
# Significance:  1.79301
# ---------
# B Threshold:  0.9898
# C Threshold:  0.3878
# Significance:  1.78705
# ---------
# B Threshold:  0.9898
# C Threshold:  0.4082
# Significance:  1.80111
# ---------
# B Threshold:  0.9898
# C Threshold:  0.4286
# Significance:  1.81303
# ---------
# B Threshold:  0.9898
# C Threshold:  0.449
# Significance:  1.80612
# ---------
# B Threshold:  0.9898
# C Threshold:  0.4694
# Significance:  1.80298
# ---------
# B Threshold:  0.9898
# C Threshold:  0.4898
# Significance:  1.8134

# %% [markdown]
# ##### Define the working points (for 2017 only)
# Xbb_points = [0.9105, 0.9714, 0.9870]
# Xcc_points = [0.9347, 0.9765, 0.9909]

# %%
fig, ax = plt.subplots()
im = ax.scatter(ddc, ddb, c=sign, s=100, marker='s', cmap='Spectral_r',linewidths=0, vmin=0., vmax=0.8)

cbar = fig.colorbar(im, ax=ax)
cbar.set_label(r'Significance ($\sigma$)')

#Plot the working points
# legend_count = 0

# for Xbb in Xbb_points:
#     for Xcc in Xcc_points:
#         if legend_count == 0:
#             plt.scatter(Xcc, Xbb, s=600, marker='*',
#                         color ='firebrick', label = r"Working points")
#         else:
#             plt.scatter(Xcc, Xbb, s=600, marker='*',
#                         color ='firebrick')
#         legend_count += 1

hep.cms.text("Preliminary")
hep.cms.lumitext(r"2017 Data, 41.5 $fb^{-1}$ (13 TeV)", fontsize=15)

plt.xlabel(r"Jet 2 $T_{Xcc}$ Cut")
plt.ylabel(r"Jet 1 $T_{Xbb}$ Cut")
plt.xlim([0.5,1])
plt.ylim(0.99,1)
plt.legend(loc='best')
#plt.xscale('log')
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
