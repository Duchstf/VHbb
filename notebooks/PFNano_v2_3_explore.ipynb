# %%
import awkward as ak
import uproot
import numpy as np
from coffea.nanoevents import NanoEventsFactory, NanoAODSchema

import matplotlib.pyplot as plt
import matplotlib.colors as colors
import mplhep as hep
plt.style.use(hep.style.ROOT)

import matplotlib.pylab as pylab
params = {'legend.fontsize': 'medium',
         'axes.labelsize': 'x-large',
         'axes.titlesize':'x-large',
         'xtick.labelsize':'medium',
         'ytick.labelsize':'medium'}
pylab.rcParams.update(params)

#line thickness
import matplotlib as mpl
mpl.rcParams['lines.linewidth'] = 5

# %%
bEnrichedSample = "root://cmsxrootd.fnal.gov//store/group/lpcpfnano/duhoang/v2_3/2016/QCD_bEnriched/QCD_bEnriched_HT500to700_TuneCP5_13TeV-madgraph-pythia8/QCD_bEnriched_HT500to700/230519_112001/0000/nano_mc2016post_15.root"
BGenFilterSample = "root://cmsxrootd.fnal.gov//store/group/lpcpfnano/duhoang/v2_3/2016/QCD_BGenFilter/QCD_HT500to700_BGenFilter_TuneCP5_13TeV-madgraph-pythia8/QCD_HT500to700_BGenFilter/230704_190939/0000/nano_mc2016post_18.root"

# %%
sample = BGenFilterSample

# one data file from 2016
fileset = {
    "Data":[sample]
}

# %%
events = NanoEventsFactory.from_root(sample, schemaclass=NanoAODSchema).events()
# Out:
# /opt/conda/lib/python3.8/site-packages/coffea/nanoevents/mapping/uproot.py:86: UserWarning: Found duplicate branch FatJetAK15SubJet_nBHadrons in <TTree 'Events' (1813 branches) at 0x7f6a67841700>, taking first instance
#   warnings.warn(
# /opt/conda/lib/python3.8/site-packages/coffea/nanoevents/mapping/uproot.py:86: UserWarning: Found duplicate branch FatJetAK15SubJet_nCHadrons in <TTree 'Events' (1813 branches) at 0x7f6a67841700>, taking first instance
#   warnings.warn(
# /opt/conda/lib/python3.8/site-packages/coffea/nanoevents/mapping/uproot.py:86: UserWarning: Found duplicate branch FatJetAK15_nBHadrons in <TTree 'Events' (1813 branches) at 0x7f6a67841700>, taking first instance
#   warnings.warn(
# /opt/conda/lib/python3.8/site-packages/coffea/nanoevents/mapping/uproot.py:86: UserWarning: Found duplicate branch FatJetAK15_nCHadrons in <TTree 'Events' (1813 branches) at 0x7f6a67841700>, taking first instance
#   warnings.warn(
# /opt/conda/lib/python3.8/site-packages/coffea/nanoevents/mapping/uproot.py:86: UserWarning: Found duplicate branch FatJet_btagDDBvLV2 in <TTree 'Events' (1813 branches) at 0x7f6a67841700>, taking first instance
#   warnings.warn(
# /opt/conda/lib/python3.8/site-packages/coffea/nanoevents/mapping/uproot.py:86: UserWarning: Found duplicate branch FatJet_btagDDCvBV2 in <TTree 'Events' (1813 branches) at 0x7f6a67841700>, taking first instance
#   warnings.warn(
# /opt/conda/lib/python3.8/site-packages/coffea/nanoevents/mapping/uproot.py:86: UserWarning: Found duplicate branch FatJet_btagDDCvLV2 in <TTree 'Events' (1813 branches) at 0x7f6a67841700>, taking first instance
#   warnings.warn(
# /opt/conda/lib/python3.8/site-packages/coffea/nanoevents/mapping/uproot.py:86: UserWarning: Found duplicate branch FatJet_nBHadrons in <TTree 'Events' (1813 branches) at 0x7f6a67841700>, taking first instance
#   warnings.warn(
# /opt/conda/lib/python3.8/site-packages/coffea/nanoevents/mapping/uproot.py:86: UserWarning: Found duplicate branch FatJet_nCHadrons in <TTree 'Events' (1813 branches) at 0x7f6a67841700>, taking first instance
#   warnings.warn(
# /opt/conda/lib/python3.8/site-packages/coffea/nanoevents/mapping/uproot.py:86: UserWarning: Found duplicate branch SubJet_nBHadrons in <TTree 'Events' (1813 branches) at 0x7f6a67841700>, taking first instance
#   warnings.warn(
# /opt/conda/lib/python3.8/site-packages/coffea/nanoevents/mapping/uproot.py:86: UserWarning: Found duplicate branch SubJet_nCHadrons in <TTree 'Events' (1813 branches) at 0x7f6a67841700>, taking first instance
#   warnings.warn(

# %%
b_quarks = events.GenPart[events.GenPart.pdgId == 5]

# %%
#Plot b quarks pt
plt.hist(ak.flatten(b_quarks.pt))
plt.xlabel('Gen B pT [GeV]')
plt.ylabel('Count')
# Out:
# Text(0, 1, 'Count')

# %%
#Plot number of b quarks 
plt.hist(np.asarray(ak.count(b_quarks.pdgId, axis=1)))
plt.xlabel('Number of Gen b quarks')
plt.ylabel('Count')
# Out:
# Text(0, 1, 'Count')

# %%
dir(b_quarks)
# Out:
# ['E',
#  'FLAGS',
#  'Mask',
#  '__class__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__get__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__self__',
#  '__self_class__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__thisclass__',
#  '_behavior',
#  '_caches',
#  '_layout',
#  '_numbaview',
#  'absolute',
#  'add',
#  'behavior',
#  'boost',
#  'boostvec',
#  'caches',
#  'children',
#  'childrenIdxG',
#  'cross',
#  'delta_phi',
#  'delta_r',
#  'delta_r2',
#  'distinctChildren',
#  'distinctChildrenDeep',
#  'distinctChildrenDeepIdxG',
#  'distinctChildrenIdxG',
#  'distinctParent',
#  'distinctParentIdxG',
#  'divide',
#  'dot',
#  'energy',
#  'eta',
#  'fields',
#  'genPartIdxMother',
#  'genPartIdxMotherG',
#  'hasFlags',
#  'layout',
#  'mask',
#  'mass',
#  'mass2',
#  'metric_table',
#  'multiply',
#  'nbytes',
#  'ndim',
#  'nearest',
#  'negative',
#  'numba_type',
#  'p',
#  'p2',
#  'parent',
#  'pdgId',
#  'phi',
#  'pt',
#  'pt2',
#  'pvec',
#  'px',
#  'py',
#  'pz',
#  'r',
#  'r2',
#  'rho',
#  'rho2',
#  'slot0',
#  'slot1',
#  'slot2',
#  'slot3',
#  'slot4',
#  'slot5',
#  'slot6',
#  'slot7',
#  'slot8',
#  'slot9',
#  'status',
#  'statusFlags',
#  'subtract',
#  'sum',
#  't',
#  'theta',
#  'to_list',
#  'to_numpy',
#  'tolist',
#  'type',
#  'unit',
#  'x',
#  'y',
#  'z']

# %%
b_quarks.status?

# %%
b_quarks.statusFlags?

# %%
dir(b_quarks)
# Out:
# ['E',
#  'FLAGS',
#  'Mask',
#  '__class__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__get__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__self__',
#  '__self_class__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__thisclass__',
#  '_behavior',
#  '_caches',
#  '_layout',
#  '_numbaview',
#  'absolute',
#  'add',
#  'behavior',
#  'boost',
#  'boostvec',
#  'caches',
#  'children',
#  'childrenIdxG',
#  'cross',
#  'delta_phi',
#  'delta_r',
#  'delta_r2',
#  'distinctChildren',
#  'distinctChildrenDeep',
#  'distinctChildrenDeepIdxG',
#  'distinctChildrenIdxG',
#  'distinctParent',
#  'distinctParentIdxG',
#  'divide',
#  'dot',
#  'energy',
#  'eta',
#  'fields',
#  'genPartIdxMother',
#  'genPartIdxMotherG',
#  'hasFlags',
#  'layout',
#  'mask',
#  'mass',
#  'mass2',
#  'metric_table',
#  'multiply',
#  'nbytes',
#  'ndim',
#  'nearest',
#  'negative',
#  'numba_type',
#  'p',
#  'p2',
#  'parent',
#  'pdgId',
#  'phi',
#  'pt',
#  'pt2',
#  'pvec',
#  'px',
#  'py',
#  'pz',
#  'r',
#  'r2',
#  'rho',
#  'rho2',
#  'slot0',
#  'slot1',
#  'slot2',
#  'slot3',
#  'slot4',
#  'slot5',
#  'slot6',
#  'slot7',
#  'slot8',
#  'slot9',
#  'status',
#  'statusFlags',
#  'subtract',
#  'sum',
#  't',
#  'theta',
#  'to_list',
#  'to_numpy',
#  'tolist',
#  'type',
#  'unit',
#  'x',
#  'y',
#  'z']

# %%
plt.hist(ak.firsts(b_quarks.status), bins=100)
# Out:
# (array([3.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#         0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#         0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#         0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 7.9000e+02,
#         0.0000e+00, 0.0000e+00, 0.0000e+00, 2.1000e+01, 0.0000e+00,
#         0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#         0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#         0.0000e+00, 0.0000e+00, 0.0000e+00, 1.6500e+02, 0.0000e+00,
#         0.0000e+00, 0.0000e+00, 1.5000e+01, 0.0000e+00, 1.3770e+03,
#         0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#         0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#         0.0000e+00, 0.0000e+00, 3.7000e+02, 0.0000e+00, 2.3400e+02,
#         0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#         0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#         0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#         0.0000e+00, 0.0000e+00, 0.0000e+00, 2.0000e+00, 0.0000e+00,
#         1.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#         0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#         0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#         0.0000e+00, 4.0019e+04, 0.0000e+00, 4.5100e+02, 7.4060e+03]),
#  array([21.  , 21.52, 22.04, 22.56, 23.08, 23.6 , 24.12, 24.64, 25.16,
#         25.68, 26.2 , 26.72, 27.24, 27.76, 28.28, 28.8 , 29.32, 29.84,
#         30.36, 30.88, 31.4 , 31.92, 32.44, 32.96, 33.48, 34.  , 34.52,
#         35.04, 35.56, 36.08, 36.6 , 37.12, 37.64, 38.16, 38.68, 39.2 ,
#         39.72, 40.24, 40.76, 41.28, 41.8 , 42.32, 42.84, 43.36, 43.88,
#         44.4 , 44.92, 45.44, 45.96, 46.48, 47.  , 47.52, 48.04, 48.56,
#         49.08, 49.6 , 50.12, 50.64, 51.16, 51.68, 52.2 , 52.72, 53.24,
#         53.76, 54.28, 54.8 , 55.32, 55.84, 56.36, 56.88, 57.4 , 57.92,
#         58.44, 58.96, 59.48, 60.  , 60.52, 61.04, 61.56, 62.08, 62.6 ,
#         63.12, 63.64, 64.16, 64.68, 65.2 , 65.72, 66.24, 66.76, 67.28,
#         67.8 , 68.32, 68.84, 69.36, 69.88, 70.4 , 70.92, 71.44, 71.96,
#         72.48, 73.  ]),
#  <BarContainer object of 100 artists>)

# %%
plt.hist(np.asarray(ak.count(b_quarks.statusFlags, axis=1)))
plt.xlabel('Number of bquarks')
# Out:
# Text(0.5, 0, 'Number of bquarks')

# %%
b_quarks.statusFlags[5]
# Out:
# <Array [] type='0 * int32[parameters={"__doc__": "gen status flags stored bitwis...'>

# %%
dir(events.GenPart)
# Out:
# ['E',
#  'FLAGS',
#  'Mask',
#  '__class__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__get__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__self__',
#  '__self_class__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__thisclass__',
#  '_behavior',
#  '_caches',
#  '_layout',
#  '_numbaview',
#  'absolute',
#  'add',
#  'behavior',
#  'boost',
#  'boostvec',
#  'caches',
#  'children',
#  'childrenIdxG',
#  'cross',
#  'delta_phi',
#  'delta_r',
#  'delta_r2',
#  'distinctChildren',
#  'distinctChildrenDeep',
#  'distinctChildrenDeepIdxG',
#  'distinctChildrenIdxG',
#  'distinctParent',
#  'distinctParentIdxG',
#  'divide',
#  'dot',
#  'energy',
#  'eta',
#  'fields',
#  'genPartIdxMother',
#  'genPartIdxMotherG',
#  'hasFlags',
#  'layout',
#  'mask',
#  'mass',
#  'mass2',
#  'metric_table',
#  'multiply',
#  'nbytes',
#  'ndim',
#  'nearest',
#  'negative',
#  'numba_type',
#  'p',
#  'p2',
#  'parent',
#  'pdgId',
#  'phi',
#  'pt',
#  'pt2',
#  'pvec',
#  'px',
#  'py',
#  'pz',
#  'r',
#  'r2',
#  'rho',
#  'rho2',
#  'slot0',
#  'slot1',
#  'slot2',
#  'slot3',
#  'slot4',
#  'slot5',
#  'slot6',
#  'slot7',
#  'slot8',
#  'slot9',
#  'status',
#  'statusFlags',
#  'subtract',
#  'sum',
#  't',
#  'theta',
#  'to_list',
#  'to_numpy',
#  'tolist',
#  'type',
#  'unit',
#  'x',
#  'y',
#  'z']

# %%
b_quarks.statusFlags 
#We want 11: fromHardProcessBeforeFSR
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 b_quarks.statusFlags
#       2 #We want 11: fromHardProcessBeforeFSR
#
# NameError: name 'b_quarks' is not defined

# %%
bin(8193)[-1:]
# Out:
# '1'

# %%
bin(20481)
# Out:
# '0b101000000000001'

# %%
events.FatJet.btagHbb
# Out:
# <Array [[-0.724, -0.00596], ... -0.903, 0.701]] type='84111 * var * float32[para...'>

# %%
dir(events.GenJet.hadronFlavour)
# Out:
# ['Mask',
#  '__class__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__get__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__self__',
#  '__self_class__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__thisclass__',
#  '_behavior',
#  '_caches',
#  '_layout',
#  '_numbaview',
#  'behavior',
#  'caches',
#  'fields',
#  'layout',
#  'mask',
#  'nbytes',
#  'ndim',
#  'numba_type',
#  'slot0',
#  'slot1',
#  'slot2',
#  'slot3',
#  'slot4',
#  'slot5',
#  'slot6',
#  'slot7',
#  'slot8',
#  'slot9',
#  'to_list',
#  'to_numpy',
#  'tolist',
#  'type']

# %%
dir(events.GenJet)
# Out:
# ['E',
#  'Mask',
#  '__class__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__get__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__self__',
#  '__self_class__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__thisclass__',
#  '_behavior',
#  '_caches',
#  '_layout',
#  '_numbaview',
#  'absolute',
#  'add',
#  'behavior',
#  'boost',
#  'boostvec',
#  'caches',
#  'cross',
#  'delta_phi',
#  'delta_r',
#  'delta_r2',
#  'divide',
#  'dot',
#  'energy',
#  'eta',
#  'fields',
#  'hadronFlavour',
#  'layout',
#  'mask',
#  'mass',
#  'mass2',
#  'metric_table',
#  'multiply',
#  'nbytes',
#  'ndim',
#  'nearest',
#  'negative',
#  'numba_type',
#  'p',
#  'p2',
#  'partonFlavour',
#  'phi',
#  'pt',
#  'pt2',
#  'pvec',
#  'px',
#  'py',
#  'pz',
#  'r',
#  'r2',
#  'rho',
#  'rho2',
#  'slot0',
#  'slot1',
#  'slot2',
#  'slot3',
#  'slot4',
#  'slot5',
#  'slot6',
#  'slot7',
#  'slot8',
#  'slot9',
#  'subtract',
#  'sum',
#  't',
#  'theta',
#  'to_list',
#  'to_numpy',
#  'tolist',
#  'type',
#  'unit',
#  'x',
#  'y',
#  'z']

# %%
dir(events)
# Out:
# ['CaloMET',
#  'ChsMET',
#  'CorrT1METJet',
#  'DeepMETResolutionTune',
#  'DeepMETResponseTune',
#  'Electron',
#  'FatJet',
#  'FatJetAK15',
#  'FatJetAK15PFCands',
#  'FatJetAK15SubJet',
#  'FatJetPFCands',
#  'FatJetSVs',
#  'Flag',
#  'FsrPhoton',
#  'GenDressedLepton',
#  'GenIsolatedPhoton',
#  'GenJet',
#  'GenJetAK15',
#  'GenJetAK8',
#  'GenMET',
#  'GenPart',
#  'GenSubJetAK15',
#  'GenVisTau',
#  'GenVtx',
#  'Generator',
#  'HLT',
#  'HLTriggerFinalPath',
#  'HLTriggerFirstPath',
#  'HTXS',
#  'IsoTrack',
#  'Jet',
#  'JetSVsAK15',
#  'L1',
#  'L1PreFiringWeight',
#  'L1Reco',
#  'L1simulation',
#  'LHE',
#  'LHEPart',
#  'LHEPdfWeight',
#  'LHEReweightingWeight',
#  'LHEScaleWeight',
#  'LHEWeight',
#  'LowPtElectron',
#  'MET',
#  'Mask',
#  'Muon',
#  'OtherPV',
#  'PFCands',
#  'PSWeight',
#  'PV',
#  'Photon',
#  'Pileup',
#  'PuppiMET',
#  'RawMET',
#  'RawPuppiMET',
#  'SV',
#  'SoftActivityJet',
#  'SoftActivityJetHT',
#  'SoftActivityJetHT10',
#  'SoftActivityJetHT2',
#  'SoftActivityJetHT5',
#  'SoftActivityJetNjets10',
#  'SoftActivityJetNjets2',
#  'SoftActivityJetNjets5',
#  'SoftDropGenJetAK15',
#  'SoftDropGenJetAK8',
#  'SubGenJetAK8',
#  'SubJet',
#  'Tau',
#  'TkMET',
#  'TrigObj',
#  '__class__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__get__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__self__',
#  '__self_class__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__thisclass__',
#  '_behavior',
#  '_caches',
#  '_layout',
#  '_numbaview',
#  'add_kind',
#  'add_systematic',
#  'behavior',
#  'boostedTau',
#  'btagWeight',
#  'caches',
#  'describe_variations',
#  'event',
#  'explodes_how',
#  'fields',
#  'fixedGridRhoFastjetAll',
#  'fixedGridRhoFastjetCentral',
#  'fixedGridRhoFastjetCentralCalo',
#  'fixedGridRhoFastjetCentralChargedPileUp',
#  'fixedGridRhoFastjetCentralNeutral',
#  'genTtbarId',
#  'genWeight',
#  'layout',
#  'luminosityBlock',
#  'mask',
#  'metadata',
#  'nbytes',
#  'ndim',
#  'numba_type',
#  'run',
#  'slot0',
#  'slot1',
#  'slot2',
#  'slot3',
#  'slot4',
#  'slot5',
#  'slot6',
#  'slot7',
#  'slot8',
#  'slot9',
#  'systematics',
#  'to_list',
#  'to_numpy',
#  'tolist',
#  'type']

# %%
dir(events.FatJet.btagHbb)
# Out:
# ['Mask',
#  '__class__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__get__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__self__',
#  '__self_class__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__thisclass__',
#  '_behavior',
#  '_caches',
#  '_layout',
#  '_numbaview',
#  'behavior',
#  'caches',
#  'fields',
#  'layout',
#  'mask',
#  'nbytes',
#  'ndim',
#  'numba_type',
#  'slot0',
#  'slot1',
#  'slot2',
#  'slot3',
#  'slot4',
#  'slot5',
#  'slot6',
#  'slot7',
#  'slot8',
#  'slot9',
#  'to_list',
#  'to_numpy',
#  'tolist',
#  'type']

# %%
dir(events)
# Out:
# ['CaloMET',
#  'ChsMET',
#  'CorrT1METJet',
#  'DeepMETResolutionTune',
#  'DeepMETResponseTune',
#  'Electron',
#  'FatJet',
#  'FatJetAK15',
#  'FatJetAK15PFCands',
#  'FatJetAK15SubJet',
#  'FatJetPFCands',
#  'FatJetSVs',
#  'Flag',
#  'FsrPhoton',
#  'GenDressedLepton',
#  'GenIsolatedPhoton',
#  'GenJet',
#  'GenJetAK15',
#  'GenJetAK8',
#  'GenMET',
#  'GenPart',
#  'GenSubJetAK15',
#  'GenVisTau',
#  'GenVtx',
#  'Generator',
#  'HLT',
#  'HLTriggerFinalPath',
#  'HLTriggerFirstPath',
#  'HTXS',
#  'IsoTrack',
#  'Jet',
#  'JetSVsAK15',
#  'L1',
#  'L1PreFiringWeight',
#  'L1Reco',
#  'L1simulation',
#  'LHE',
#  'LHEPart',
#  'LHEPdfWeight',
#  'LHEReweightingWeight',
#  'LHEScaleWeight',
#  'LHEWeight',
#  'LowPtElectron',
#  'MET',
#  'Mask',
#  'Muon',
#  'OtherPV',
#  'PFCands',
#  'PSWeight',
#  'PV',
#  'Photon',
#  'Pileup',
#  'PuppiMET',
#  'RawMET',
#  'RawPuppiMET',
#  'SV',
#  'SoftActivityJet',
#  'SoftActivityJetHT',
#  'SoftActivityJetHT10',
#  'SoftActivityJetHT2',
#  'SoftActivityJetHT5',
#  'SoftActivityJetNjets10',
#  'SoftActivityJetNjets2',
#  'SoftActivityJetNjets5',
#  'SoftDropGenJetAK15',
#  'SoftDropGenJetAK8',
#  'SubGenJetAK8',
#  'SubJet',
#  'Tau',
#  'TkMET',
#  'TrigObj',
#  '__class__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__get__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__self__',
#  '__self_class__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__thisclass__',
#  '_behavior',
#  '_caches',
#  '_layout',
#  '_numbaview',
#  'add_kind',
#  'add_systematic',
#  'behavior',
#  'boostedTau',
#  'btagWeight',
#  'caches',
#  'describe_variations',
#  'event',
#  'explodes_how',
#  'fields',
#  'fixedGridRhoFastjetAll',
#  'fixedGridRhoFastjetCentral',
#  'fixedGridRhoFastjetCentralCalo',
#  'fixedGridRhoFastjetCentralChargedPileUp',
#  'fixedGridRhoFastjetCentralNeutral',
#  'genTtbarId',
#  'genWeight',
#  'layout',
#  'luminosityBlock',
#  'mask',
#  'metadata',
#  'nbytes',
#  'ndim',
#  'numba_type',
#  'run',
#  'slot0',
#  'slot1',
#  'slot2',
#  'slot3',
#  'slot4',
#  'slot5',
#  'slot6',
#  'slot7',
#  'slot8',
#  'slot9',
#  'systematics',
#  'to_list',
#  'to_numpy',
#  'tolist',
#  'type']

# %%
candidatejet = events.FatJet[:, :2]
candidatejet = ak.firsts(candidatejet)

# %%
events.SubJet
# Out:
# <PtEtaPhiMCollectionArray [[{btagCSVV2: 0.0738, ... ] type='84111 * var * struct...'>
