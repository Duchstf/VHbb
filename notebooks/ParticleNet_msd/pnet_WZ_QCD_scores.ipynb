# %%
import os, subprocess
import json
import uproot3
import awkward as ak
import numpy as np
from coffea import processor, util, hist
import pickle
import pandas as pd

#Plot settings
# %matplotlib inline
import matplotlib.pyplot as plt
import mplhep as hep
plt.style.use(hep.style.CMS)
# Out:
# /opt/conda/lib/python3.8/site-packages/coffea/util.py:154: FutureWarning: In coffea version v2023.3.0 (target date: 31 Mar 2023), this will be an error.
# (Set coffea.deprecations_as_errors = True to get a stack trace now.)
# ImportError: coffea.hist is deprecated
#   warnings.warn(message, FutureWarning)

# %%
pickle_path = '../../output/pickle/pnet_WZ_QCD_scores/2017/templates.pkl'

# %%
#Load the templates
coffea_hist = pickle.load(open(pickle_path,'rb'))

# %%
coffea_hist
# Out:
# <Hist (process,region,xbb1,xcc2,xqq2,w2,z2) instance at 0x7f80404bb3a0>

# %% [markdown]
# ## Jet 1 b scores

# %%
hist.plot1d(coffea_hist.integrate('region','signal').sum('xcc2','xqq2','w2','z2').integrate('process', 'QCD'))
# Out:
# <Axes: xlabel='Jet 1 Xbb Score', ylabel='Events'>

# %%
hist.plot1d(coffea_hist.integrate('region','signal').sum('xcc2','xqq2','w2','z2').integrate('process', 'ZH'))
# Out:
# <Axes: xlabel='Jet 1 Xbb Score', ylabel='Events'>

# %%
hist.plot1d(coffea_hist.integrate('region','signal').sum('xcc2','xqq2','w2','z2').integrate('process', 'WH'))
# Out:
# <Axes: xlabel='Jet 1 Xbb Score', ylabel='Events'>

# %% [markdown]
# ----

# %% [markdown]
# ## Jet 2 cc scores

# %%
hist.plot1d(coffea_hist.integrate('region','signal').sum('xbb1','xqq2','w2','z2').integrate('process', 'QCD'))
# Out:
# <Axes: xlabel='Jet 2 Xcc Score', ylabel='Events'>

# %%
hist.plot1d(coffea_hist.integrate('region','signal').sum('xbb1','xqq2','w2','z2').integrate('process', 'ZH'))
# Out:
# <Axes: xlabel='Jet 2 Xcc Score', ylabel='Events'>

# %%
hist.plot1d(coffea_hist.integrate('region','signal').sum('xbb1','xqq2','w2','z2').integrate('process', 'WH'))
# Out:
# <Axes: xlabel='Jet 2 Xcc Score', ylabel='Events'>

# %% [markdown]
# ----

# %% [markdown]
# ## Jet 2 qq scores

# %%
hist.plot1d(coffea_hist.integrate('region','signal').sum('xbb1','xcc2','w2','z2').integrate('process', 'QCD'))
# Out:
# <Axes: xlabel='Jet 2 Xqq Score', ylabel='Events'>

# %%
hist.plot1d(coffea_hist.integrate('region','signal').sum('xbb1','xcc2','w2','z2').integrate('process', 'ZH'))
# Out:
# <Axes: xlabel='Jet 2 Xqq Score', ylabel='Events'>

# %%
hist.plot1d(coffea_hist.integrate('region','signal').sum('xbb1','xcc2','w2','z2').integrate('process', 'WH'))
# Out:
# <Axes: xlabel='Jet 2 Xqq Score', ylabel='Events'>

# %% [markdown]
# -------

# %% [markdown]
# -----

# %%
hist.plot1d(coffea_hist.integrate('region','signal').sum('xbb1','xcc2','xqq2','z2').integrate('process', 'QCD'))
# Out:
# <Axes: xlabel='Jet 2 WvsQCDScore', ylabel='Events'>

# %%
hist.plot1d(coffea_hist.integrate('region','signal').sum('xbb1','xcc2','xqq2','z2').integrate('process', 'ZH'))
# Out:
# <Axes: xlabel='Jet 2 WvsQCDScore', ylabel='Events'>

# %%
hist.plot1d(coffea_hist.integrate('region','signal').sum('xbb1','xcc2','xqq2','z2').integrate('process', 'WH'))
# Out:
# <Axes: xlabel='Jet 2 WvsQCDScore', ylabel='Events'>

# %% [markdown]
# ----

# %%
hist.plot1d(coffea_hist.integrate('region','signal').sum('xbb1','xcc2','xqq2','w2').integrate('process', 'QCD'))
# Out:
# <Axes: xlabel='Jet 2 ZvsQCDScore', ylabel='Events'>

# %%
hist.plot1d(coffea_hist.integrate('region','signal').sum('xbb1','xcc2','xqq2','w2').integrate('process', 'ZH'))
# Out:
# <Axes: xlabel='Jet 2 ZvsQCDScore', ylabel='Events'>

# %%
hist.plot1d(coffea_hist.integrate('region','signal').sum('xbb1','xcc2','xqq2','w2').integrate('process', 'WH'))
# Out:
# <Axes: xlabel='Jet 2 ZvsQCDScore', ylabel='Events'>

# %% [markdown]
# ------

# %%
hist.plot1d(coffea_hist.integrate('region','signal').sum('xbb1','xqq2','w2').integrate('process', 'QCD').integrate('xcc2',slice(0.8,1)))
# Out:
# <Axes: xlabel='Jet 2 ZvsQCDScore', ylabel='Events'>

# %%
hist.plot1d(coffea_hist.integrate('region','signal').sum('xbb1','xqq2','w2').integrate('process', 'ZH').integrate('xcc2',slice(0.8,1)))
# Out:
# <Axes: xlabel='Jet 2 ZvsQCDScore', ylabel='Events'>

# %%
hist.plot1d(coffea_hist.integrate('region','signal').sum('xbb1','xqq2','z2').integrate('process', 'QCD').integrate('xcc2',slice(0.8,1)))
# Out:
# <Axes: xlabel='Jet 2 WvsQCDScore', ylabel='Events'>
