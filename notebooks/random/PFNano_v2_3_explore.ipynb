# %%
import awkward as ak
import uproot
import numpy as np
from coffea.nanoevents import NanoEventsFactory, NanoAODSchema

import matplotlib.pyplot as plt
import matplotlib.colors as colors
import mplhep as hep
plt.style.use(hep.style.ROOT)

import matplotlib.pylab as pylab
params = {'legend.fontsize': 'medium',
         'axes.labelsize': 'x-large',
         'axes.titlesize':'x-large',
         'xtick.labelsize':'medium',
         'ytick.labelsize':'medium'}
pylab.rcParams.update(params)

#line thickness
import matplotlib as mpl
mpl.rcParams['lines.linewidth'] = 5

# %%
bEnrichedSample = "root://cmsxrootd.fnal.gov//store/group/lpcpfnano/duhoang/v2_3/2016/QCD_bEnriched/QCD_bEnriched_HT500to700_TuneCP5_13TeV-madgraph-pythia8/QCD_bEnriched_HT500to700/230519_112001/0000/nano_mc2016post_15.root"
BGenFilterSample = "root://cmsxrootd.fnal.gov//store/group/lpcpfnano/duhoang/v2_3/2016/QCD_BGenFilter/QCD_HT500to700_BGenFilter_TuneCP5_13TeV-madgraph-pythia8/QCD_HT500to700_BGenFilter/230704_190939/0000/nano_mc2016post_18.root"

# %%
sample = bEnrichedSample

# one data file from 2016
fileset = {
    "Data":[sample]
}

# %%
events = NanoEventsFactory.from_root(sample, schemaclass=NanoAODSchema).events()
# Out:
# /opt/conda/lib/python3.8/site-packages/coffea/nanoevents/mapping/uproot.py:86: UserWarning: Found duplicate branch FatJetAK15SubJet_nBHadrons in <TTree 'Events' (1813 branches) at 0x7efc605fbaf0>, taking first instance
#   warnings.warn(
# /opt/conda/lib/python3.8/site-packages/coffea/nanoevents/mapping/uproot.py:86: UserWarning: Found duplicate branch FatJetAK15SubJet_nCHadrons in <TTree 'Events' (1813 branches) at 0x7efc605fbaf0>, taking first instance
#   warnings.warn(
# /opt/conda/lib/python3.8/site-packages/coffea/nanoevents/mapping/uproot.py:86: UserWarning: Found duplicate branch FatJetAK15_nBHadrons in <TTree 'Events' (1813 branches) at 0x7efc605fbaf0>, taking first instance
#   warnings.warn(
# /opt/conda/lib/python3.8/site-packages/coffea/nanoevents/mapping/uproot.py:86: UserWarning: Found duplicate branch FatJetAK15_nCHadrons in <TTree 'Events' (1813 branches) at 0x7efc605fbaf0>, taking first instance
#   warnings.warn(
# ...

# %%
dir(events.FatJet)
# Out:
# ['DDX_jetNSecondaryVertices',
#  'DDX_jetNTracks',
#  'DDX_tau1_flightDistance2dSig',
#  'DDX_tau1_trackEtaRel_0',
#  'DDX_tau1_trackEtaRel_1',
#  'DDX_tau1_trackEtaRel_2',
#  'DDX_tau1_trackSip3dSig_0',
#  'DDX_tau1_trackSip3dSig_1',
#  'DDX_tau1_vertexDeltaR',
#  'DDX_tau1_vertexEnergyRatio',
#  'DDX_tau1_vertexMass',
#  'DDX_tau2_flightDistance2dSig',
#  'DDX_tau2_trackEtaRel_0',
#  'DDX_tau2_trackEtaRel_1',
#  'DDX_tau2_trackEtaRel_3',
#  'DDX_tau2_trackSip3dSig_0',
#  'DDX_tau2_trackSip3dSig_1',
#  'DDX_tau2_vertexEnergyRatio',
#  'DDX_tau2_vertexMass',
#  'DDX_trackSip2dSigAboveBottom_0',
#  'DDX_trackSip2dSigAboveBottom_1',
#  'DDX_trackSip2dSigAboveCharm',
#  'DDX_trackSip3dSig_0',
#  'DDX_trackSip3dSig_1',
#  'DDX_trackSip3dSig_2',
#  'DDX_trackSip3dSig_3',
#  'DDX_z_ratio',
#  'E',
#  'LOOSE',
#  'Mask',
#  'Proba',
#  'TIGHT',
#  'TIGHTLEPVETO',
#  '__class__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__get__',
# ...

# %%
b_quarks = events.GenPart[(events.GenPart.pdgId == 5) & (events.GenPart.status < 30)]

# %%
b_quarks
# Out:
# <GenParticleArray [[GenParticle], ... GenParticle]] type='110095 * var * genPart...'>

# %%
#Plot b quarks pt
plt.hist(ak.flatten(b_quarks.pt))
plt.xlabel('Gen B pT [GeV]')
plt.ylabel('Count')
# Out:
# Text(0, 1, 'Count')

# %%
#Plot number of b quarks 
plt.hist(np.asarray(ak.count(b_quarks.pdgId, axis=1)))
plt.xlabel('Number of Gen b quarks')
plt.ylabel('Count')
# Out:
# Text(0, 1, 'Count')

# %%
dir(b_quarks)
# Out:
# ['E',
#  'FLAGS',
#  'Mask',
#  '__class__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__get__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__self__',
#  '__self_class__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__thisclass__',
#  '_behavior',
#  '_caches',
#  '_layout',
#  '_numbaview',
#  'absolute',
#  'add',
#  'behavior',
#  'boost',
#  'boostvec',
#  'caches',
#  'children',
#  'childrenIdxG',
#  'cross',
#  'delta_phi',
#  'delta_r',
#  'delta_r2',
#  'distinctChildren',
#  'distinctChildrenDeep',
#  'distinctChildrenDeepIdxG',
#  'distinctChildrenIdxG',
#  'distinctParent',
#  'distinctParentIdxG',
#  'divide',
#  'dot',
#  'energy',
#  'eta',
#  'fields',
#  'genPartIdxMother',
#  'genPartIdxMotherG',
#  'hasFlags',
#  'layout',
# ...

# %%
b_quarks.status?

# %%
b_quarks.statusFlags?

# %%
dir(b_quarks)
# Out:
# ['E',
#  'FLAGS',
#  'Mask',
#  '__class__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__get__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__self__',
#  '__self_class__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__thisclass__',
#  '_behavior',
#  '_caches',
#  '_layout',
#  '_numbaview',
#  'absolute',
#  'add',
#  'behavior',
#  'boost',
#  'boostvec',
#  'caches',
#  'children',
#  'childrenIdxG',
#  'cross',
#  'delta_phi',
#  'delta_r',
#  'delta_r2',
#  'distinctChildren',
#  'distinctChildrenDeep',
#  'distinctChildrenDeepIdxG',
#  'distinctChildrenIdxG',
#  'distinctParent',
#  'distinctParentIdxG',
#  'divide',
#  'dot',
#  'energy',
#  'eta',
#  'fields',
#  'genPartIdxMother',
#  'genPartIdxMotherG',
#  'hasFlags',
#  'layout',
# ...

# %%
b_quarks
# Out:
# <GenParticleArray [[], [], ... [GenParticle], []] type='84176 * var * genParticle'>

# %%
plt.hist(ak.flatten(b_quarks.status), bins=100)
# Out:
# (array([3.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#         0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#         0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#         0.000e+00, 7.930e+02, 0.000e+00, 0.000e+00, 0.000e+00, 3.600e+01,
#         0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#         0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#         0.000e+00, 0.000e+00, 1.830e+02, 0.000e+00, 0.000e+00, 0.000e+00,
#         1.900e+01, 0.000e+00, 1.542e+03, 0.000e+00, 0.000e+00, 0.000e+00,
#         0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#         0.000e+00, 0.000e+00, 0.000e+00, 4.110e+02, 0.000e+00, 2.660e+02,
#         0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#         0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#         0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
# ...

# %%
plt.hist(np.asarray(ak.count(b_quarks.statusFlags, axis=1)))
plt.xlabel('Number of bquarks')
# Out:
# Text(0.5, 0, 'Number of bquarks')

# %%
b_quarks.statusFlags[5]
# Out:
# <Array [] type='0 * int32[parameters={"__doc__": "gen status flags stored bitwis...'>

# %%
dir(events.GenPart)
# Out:
# ['E',
#  'FLAGS',
#  'Mask',
#  '__class__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__get__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__self__',
#  '__self_class__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__thisclass__',
#  '_behavior',
#  '_caches',
#  '_layout',
#  '_numbaview',
#  'absolute',
#  'add',
#  'behavior',
#  'boost',
#  'boostvec',
#  'caches',
#  'children',
#  'childrenIdxG',
#  'cross',
#  'delta_phi',
#  'delta_r',
#  'delta_r2',
#  'distinctChildren',
#  'distinctChildrenDeep',
#  'distinctChildrenDeepIdxG',
#  'distinctChildrenIdxG',
#  'distinctParent',
#  'distinctParentIdxG',
#  'divide',
#  'dot',
#  'energy',
#  'eta',
#  'fields',
#  'genPartIdxMother',
#  'genPartIdxMotherG',
#  'hasFlags',
#  'layout',
# ...

# %%
b_quarks.statusFlags 
#We want 11: fromHardProcessBeforeFSR
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 b_quarks.statusFlags
#       2 #We want 11: fromHardProcessBeforeFSR
#
# NameError: name 'b_quarks' is not defined

# %%
bin(8193)[-1:]
# Out:
# '1'

# %%
bin(20481)
# Out:
# '0b101000000000001'

# %%
events.FatJet.btagHbb
# Out:
# <Array [[-0.724, -0.00596], ... -0.903, 0.701]] type='84111 * var * float32[para...'>

# %%
dir(events.GenJet.hadronFlavour)
# Out:
# ['Mask',
#  '__class__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__get__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__self__',
#  '__self_class__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__thisclass__',
#  '_behavior',
#  '_caches',
#  '_layout',
#  '_numbaview',
#  'behavior',
#  'caches',
#  'fields',
#  'layout',
#  'mask',
#  'nbytes',
#  'ndim',
#  'numba_type',
#  'slot0',
#  'slot1',
#  'slot2',
#  'slot3',
#  'slot4',
#  'slot5',
#  'slot6',
#  'slot7',
#  'slot8',
#  'slot9',
#  'to_list',
#  'to_numpy',
#  'tolist',
#  'type']

# %%
dir(events.GenJet)
# Out:
# ['E',
#  'Mask',
#  '__class__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__get__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__self__',
#  '__self_class__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__thisclass__',
#  '_behavior',
#  '_caches',
#  '_layout',
#  '_numbaview',
#  'absolute',
#  'add',
#  'behavior',
#  'boost',
#  'boostvec',
#  'caches',
#  'cross',
#  'delta_phi',
#  'delta_r',
#  'delta_r2',
#  'divide',
#  'dot',
#  'energy',
#  'eta',
#  'fields',
#  'hadronFlavour',
#  'layout',
#  'mask',
#  'mass',
#  'mass2',
#  'metric_table',
#  'multiply',
#  'nbytes',
#  'ndim',
#  'nearest',
#  'negative',
#  'numba_type',
#  'p',
#  'p2',
#  'partonFlavour',
#  'phi',
#  'pt',
#  'pt2',
#  'pvec',
#  'px',
#  'py',
#  'pz',
# ...

# %%
dir(events)
# Out:
# ['CaloMET',
#  'ChsMET',
#  'CorrT1METJet',
#  'DeepMETResolutionTune',
#  'DeepMETResponseTune',
#  'Electron',
#  'FatJet',
#  'FatJetAK15',
#  'FatJetAK15PFCands',
#  'FatJetAK15SubJet',
#  'FatJetPFCands',
#  'FatJetSVs',
#  'Flag',
#  'FsrPhoton',
#  'GenDressedLepton',
#  'GenIsolatedPhoton',
#  'GenJet',
#  'GenJetAK15',
#  'GenJetAK8',
#  'GenMET',
#  'GenPart',
#  'GenSubJetAK15',
#  'GenVisTau',
#  'GenVtx',
#  'Generator',
#  'HLT',
#  'HLTriggerFinalPath',
#  'HLTriggerFirstPath',
#  'HTXS',
#  'IsoTrack',
#  'Jet',
#  'JetSVsAK15',
#  'L1',
#  'L1PreFiringWeight',
#  'L1Reco',
#  'L1simulation',
#  'LHE',
#  'LHEPart',
#  'LHEPdfWeight',
#  'LHEReweightingWeight',
#  'LHEScaleWeight',
#  'LHEWeight',
#  'LowPtElectron',
#  'MET',
#  'Mask',
#  'Muon',
#  'OtherPV',
#  'PFCands',
#  'PSWeight',
#  'PV',
#  'Photon',
#  'Pileup',
#  'PuppiMET',
#  'RawMET',
#  'RawPuppiMET',
#  'SV',
#  'SoftActivityJet',
#  'SoftActivityJetHT',
#  'SoftActivityJetHT10',
# ...

# %%
dir(events.FatJet.btagHbb)
# Out:
# ['Mask',
#  '__class__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__get__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__self__',
#  '__self_class__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__thisclass__',
#  '_behavior',
#  '_caches',
#  '_layout',
#  '_numbaview',
#  'behavior',
#  'caches',
#  'fields',
#  'layout',
#  'mask',
#  'nbytes',
#  'ndim',
#  'numba_type',
#  'slot0',
#  'slot1',
#  'slot2',
#  'slot3',
#  'slot4',
#  'slot5',
#  'slot6',
#  'slot7',
#  'slot8',
#  'slot9',
#  'to_list',
#  'to_numpy',
#  'tolist',
#  'type']

# %%
dir(events)
# Out:
# ['CaloMET',
#  'ChsMET',
#  'CorrT1METJet',
#  'DeepMETResolutionTune',
#  'DeepMETResponseTune',
#  'Electron',
#  'FatJet',
#  'FatJetAK15',
#  'FatJetAK15PFCands',
#  'FatJetAK15SubJet',
#  'FatJetPFCands',
#  'FatJetSVs',
#  'Flag',
#  'FsrPhoton',
#  'GenDressedLepton',
#  'GenIsolatedPhoton',
#  'GenJet',
#  'GenJetAK15',
#  'GenJetAK8',
#  'GenMET',
#  'GenPart',
#  'GenSubJetAK15',
#  'GenVisTau',
#  'GenVtx',
#  'Generator',
#  'HLT',
#  'HLTriggerFinalPath',
#  'HLTriggerFirstPath',
#  'HTXS',
#  'IsoTrack',
#  'Jet',
#  'JetSVsAK15',
#  'L1',
#  'L1PreFiringWeight',
#  'L1Reco',
#  'L1simulation',
#  'LHE',
#  'LHEPart',
#  'LHEPdfWeight',
#  'LHEReweightingWeight',
#  'LHEScaleWeight',
#  'LHEWeight',
#  'LowPtElectron',
#  'MET',
#  'Mask',
#  'Muon',
#  'OtherPV',
#  'PFCands',
#  'PSWeight',
#  'PV',
#  'Photon',
#  'Pileup',
#  'PuppiMET',
#  'RawMET',
#  'RawPuppiMET',
#  'SV',
#  'SoftActivityJet',
#  'SoftActivityJetHT',
#  'SoftActivityJetHT10',
# ...

# %%
candidatejet = events.FatJet[:, :2]
candidatejet = ak.firsts(candidatejet)

# %%
events.SubJet
# Out:
# <PtEtaPhiMCollectionArray [[{btagCSVV2: 0.0738, ... ] type='84111 * var * struct...'>

# %% [markdown]
# ----

# %%
QCD_sample = "root://cmsxrootd.fnal.gov//store/user/lpcpfnano/cmantill/v2_3/2017/QCD/QCD_HT1000to1500_TuneCP5_PSWeights_13TeV-madgraph-pythia8/QCD_HT1000to1500/220808_164439/0000/nano_mc2017_1-20.root"

# %%
QCD_events = NanoEventsFactory.from_root(QCD_sample, schemaclass=NanoAODSchema).events()
# Out:
# /opt/conda/lib/python3.8/site-packages/coffea/nanoevents/mapping/uproot.py:86: UserWarning: Found duplicate branch FatJetAK15SubJet_nBHadrons in <TTree 'Events' (1975 branches) at 0x7efc4f4b4b50>, taking first instance
#   warnings.warn(
# /opt/conda/lib/python3.8/site-packages/coffea/nanoevents/mapping/uproot.py:86: UserWarning: Found duplicate branch FatJetAK15SubJet_nCHadrons in <TTree 'Events' (1975 branches) at 0x7efc4f4b4b50>, taking first instance
#   warnings.warn(
# /opt/conda/lib/python3.8/site-packages/coffea/nanoevents/mapping/uproot.py:86: UserWarning: Found duplicate branch FatJetAK15_nBHadrons in <TTree 'Events' (1975 branches) at 0x7efc4f4b4b50>, taking first instance
#   warnings.warn(
# /opt/conda/lib/python3.8/site-packages/coffea/nanoevents/mapping/uproot.py:86: UserWarning: Found duplicate branch FatJetAK15_nCHadrons in <TTree 'Events' (1975 branches) at 0x7efc4f4b4b50>, taking first instance
#   warnings.warn(
# ...

# %%
fat_jets = ak.firsts(QCD_events.FatJet)

# %%
# secondjet.particleNetMD_Xcc / (secondjet.particleNetMD_Xbb +\
#                                                 secondjet.particleNetMD_QCD +\
#                                                 secondjet.particleNetMD_Xcc +\
#                                                 secondjet.particleNetMD_Xqq)

# %%
Xcc = ak.flatten(QCD_events.FatJet.particleNetMD_Xcc)
Xbb = ak.flatten(QCD_events.FatJet.particleNetMD_Xbb)
QCDX= ak.flatten(QCD_events.FatJet.particleNetMD_QCD)
Xqq = ak.flatten(QCD_events.FatJet.particleNetMD_Xqq)

# %%
test_score = Xcc/(1-Xbb-Xqq)

# %%
test_score_bb = Xbb/(1-Xcc-Xqq)

# %%
plt.hist(test_score_bb, bins=100)
plt.xscale('log')

# %%
test_score_bb = Xbb/(Xbb + Xcc + QCDX + Xqq)

# %%
plt.hist(test_score, bins=100)
plt.xscale('log')

# %%
plt.hist(test_score, bins=100)
plt.xscale('log')

# %%
WH_sample = "root://cmsxrootd.fnal.gov//store/user/lpcpfnano/cmantill/v2_3/2017/HToBB/WplusH_HToBB_WToQQ_M-125_TuneCP5_13TeV-powheg-pythia8/WplusH_HToBB_WToQQ/230217_201113/0000/nano_mc2017_1-137.root"

# %%
WH_events = NanoEventsFactory.from_root(WH_sample, schemaclass=NanoAODSchema).events()
# Out:
# /opt/conda/lib/python3.8/site-packages/coffea/nanoevents/mapping/uproot.py:86: UserWarning: Found duplicate branch FatJetAK15SubJet_nBHadrons in <TTree 'Events' (1975 branches) at 0x7efc4ccd79d0>, taking first instance
#   warnings.warn(
# /opt/conda/lib/python3.8/site-packages/coffea/nanoevents/mapping/uproot.py:86: UserWarning: Found duplicate branch FatJetAK15SubJet_nCHadrons in <TTree 'Events' (1975 branches) at 0x7efc4ccd79d0>, taking first instance
#   warnings.warn(
# /opt/conda/lib/python3.8/site-packages/coffea/nanoevents/mapping/uproot.py:86: UserWarning: Found duplicate branch FatJetAK15_nBHadrons in <TTree 'Events' (1975 branches) at 0x7efc4ccd79d0>, taking first instance
#   warnings.warn(
# /opt/conda/lib/python3.8/site-packages/coffea/nanoevents/mapping/uproot.py:86: UserWarning: Found duplicate branch FatJetAK15_nCHadrons in <TTree 'Events' (1975 branches) at 0x7efc4ccd79d0>, taking first instance
#   warnings.warn(
# ...

# %%
aXcc = ak.flatten(WH_events.FatJet.particleNetMD_Xcc)
aXbb = ak.flatten(WH_events.FatJet.particleNetMD_Xbb)
aQCDX= ak.flatten(WH_events.FatJet.particleNetMD_QCD)
aXqq = ak.flatten(WH_events.FatJet.particleNetMD_Xqq)

# %%
a_test = aXcc/(1- aXbb - aXqq)

# %%
a_test_bb = aXbb/(1 - aXcc - aXqq)

# %%
plt.hist(a_test, bins=100)
#plt.xscale('log')
# Out:
# (array([1326.,  341.,  272.,  220.,  191.,  155.,  119.,  113.,  100.,
#          109.,   89.,   82.,   80.,   70.,   69.,   68.,   60.,   54.,
#           56.,   57.,   59.,   42.,   47.,   48.,   44.,   32.,   42.,
#           34.,   39.,   37.,   43.,   38.,   29.,   30.,   34.,   43.,
#           30.,   24.,   30.,   20.,   25.,   27.,   32.,   32.,   29.,
#           28.,   29.,   26.,   31.,   25.,   26.,   26.,   31.,   24.,
#           22.,   27.,   31.,   21.,   23.,   21.,   19.,   24.,   17.,
#           18.,   26.,   26.,   34.,   31.,   23.,   20.,   19.,   17.,
#           28.,   27.,   22.,   15.,   22.,   25.,   15.,   31.,   19.,
#           30.,   28.,   29.,   22.,   23.,   30.,   26.,   37.,   31.,
#           32.,   37.,   29.,   35.,   34.,   46.,   42.,   47.,   53.,
#           59.]),
#  array([0.        , 0.0099915 , 0.01998301, 0.02997451, 0.03996602,
#         0.04995752, 0.05994903, 0.06994053, 0.07993203, 0.08992354,
# ...

# %%
plt.hist(a_test, bins = 100)
plt.xscale('log')

# %%
plt.hist(a_test, bins = 100, alpha=0.3)
plt.hist(test_score, bins=100, alpha=0.3)

plt.xscale('log')
